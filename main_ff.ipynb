# %%
from features.firefly import *
from config import config as cfg
from pathlib import Path

# %%
ff = FireflyOptimization(2, 5, 1.0, 0.2, 1.0, 50)
# Out:
# First solution: [[0.86, 0.14], [0.44, 0.56], [0.6, 0.4], [0.01, 0.99], [0.78, 0.22]]
# Optimized weights solution for gen. = 1: [[0.01, 0.99], [0.86, 0.14], [0.78, 0.22], [0.44, 0.56], [0.6, 0.4]]
# Metric avg: [0.6593709, 0.65659344, 0.65522283, 0.6357345, 0.63521385]
# --
#
# Optimized weights solution for gen. = 2: [[0.01, 0.99], [0.86, 0.14], [0.78, 0.22], [0.44, 0.56], [0.6, 0.4]]
# Metric avg: [0.6593709, 0.65659344, 0.65522283, 0.6357345, 0.63521385]
# --
#
# Optimized weights solution for gen. = 3: [[0.01, 0.99], [0.86, 0.14], [0.78, 0.22], [0.44, 0.56], [0.6, 0.4]]
# Metric avg: [0.6593709, 0.65659344, 0.65522283, 0.6357345, 0.63521385]
# --
#
# Optimized weights solution for gen. = 4: [[0.01, 0.99], [0.86, 0.14], [0.78, 0.22], [0.44, 0.56], [0.6, 0.4]]
# Metric avg: [0.6593709, 0.65659344, 0.65522283, 0.6357345, 0.63521385]
# --
#
# Optimized weights solution for gen. = 5: [[0.01, 0.99], [0.86, 0.14], [0.78, 0.22], [0.44, 0.56], [0.6, 0.4]]
# ...
