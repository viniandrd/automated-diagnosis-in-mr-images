# %%
from features.firefly import *
from features.firefly_algorithm import *
from custom_objects.custom_metrics import *
from config import config as cfg
from pathlib import Path
import numpy as np
from numpy.random import default_rng
import random

# %%
#best = Firefly(metric.iou_result, max_evals=1000)
best = FireflyOptimization(2, 50, 1.0, 0.1, 1.0, 1000)
# Out:
# First solution: [[0.37387, 0.62613], [0.01686, 0.98314], [0.27115, 0.72885], [0.56972, 0.43028], [0.4542, 0.5458], [0.69712, 0.30288], [0.28695, 0.71305], [0.89009, 0.10991], [0.35078, 0.64922], [0.15486, 0.84514], [0.06902, 0.93098], [0.6307, 0.3693], [0.66409, 0.33591], [0.2389, 0.7611], [0.49133, 0.50867], [0.63901, 0.36099], [0.74363, 0.25637], [0.35004, 0.64996], [0.81657, 0.18343], [0.00025, 0.99975], [0.60064, 0.39936], [0.99307, 0.00693], [0.67744, 0.32256], [0.29237, 0.70763], [0.45214, 0.54786], [0.65112, 0.34888], [0.23596, 0.76404], [0.18949, 0.81051], [0.552, 0.448], [0.47545, 0.52455], [0.52717, 0.47283], [0.32628, 0.67372], [0.00197, 0.99803], [0.73558, 0.26442], [0.58905, 0.41095], [0.33992, 0.66008], [0.47084, 0.52916], [0.4265, 0.5735], [0.47767, 0.52233], [0.62233, 0.37767], [0.08993, 0.91007], [0.09602, 0.90398], [0.29342, 0.70658], [0.64467, 0.35533], [0.67874, 0.32126], [0.35224, 0.64776], [0.9586, 0.0414], [0.54684, 0.45316], [0.67539, 0.32461], [0.33405, 0.665
# ...
